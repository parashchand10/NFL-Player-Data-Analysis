# %% [markdown]
# # <center>**Game Data**</center>
# <img src="https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F3258%2F820e86013d48faacf33b7a32a15e814c%2FIncreasing%20Dir%20and%20O.png?generation=1572285857588233&alt=media" alt="image_name" width="100%" height="100%">

# %%
#Import library to run the task

import pandas as pd  

import matplotlib.pyplot as plt

import seaborn as sns

# %%
games = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2024/games.csv")

games
# Out:
#          gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0    2022090800    2022     1  09/08/2022        20:20:00           LA
# 1    2022091100    2022     1  09/11/2022        13:00:00          ATL
# 2    2022091101    2022     1  09/11/2022        13:00:00          CAR
# 3    2022091102    2022     1  09/11/2022        13:00:00          CHI
# 4    2022091103    2022     1  09/11/2022        13:00:00          CIN
# ..          ...     ...   ...         ...             ...          ...
# 131  2022110607    2022     9  11/06/2022        13:00:00          WAS
# 132  2022110608    2022     9  11/06/2022        16:05:00          ARI
# 133  2022110609    2022     9  11/06/2022        16:25:00           TB
# 134  2022110610    2022     9  11/06/2022        20:20:00           KC
# 135  2022110700    2022     9  11/07/2022        20:15:00           NO
#
#     visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0               BUF              10                 31
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gameId             136 non-null    int64
#  1   season             136 non-null    int64
#  2   week               136 non-null    int64
#  3   gameDate           136 non-null    object
#  4   gameTimeEastern    136 non-null    object
#  5   homeTeamAbbr       136 non-null    object
#  6   visitorTeamAbbr    136 non-null    object
#  7   homeFinalScore     136 non-null    int64
#  8   visitorFinalScore  136 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 9.7+ KB

# %%
games.count()
# Out:
# gameId               136
# season               136
# week                 136
# gameDate             136
# gameTimeEastern      136
# homeTeamAbbr         136
# visitorTeamAbbr      136
# homeFinalScore       136
# visitorFinalScore    136
# dtype: int64

# %%
games.count().sum()
# Out:
# 1224

# %%
games.nunique()
# Out:
# gameId               136
# season                 1
# week                   9
# gameDate              27
# gameTimeEastern        8
# homeTeamAbbr          32
# visitorTeamAbbr       32
# homeFinalScore        38
# visitorFinalScore     35
# dtype: int64

# %%
nflgame = games.copy()

# %%
nflgame['gameDate'] = pd.to_datetime(nflgame['gameDate'], errors = 'coerce')

# %%
nflgame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gameId             136 non-null    int64
#  1   season             136 non-null    int64
#  2   week               136 non-null    int64
#  3   gameDate           136 non-null    datetime64[ns]
#  4   gameTimeEastern    136 non-null    object
#  5   homeTeamAbbr       136 non-null    object
#  6   visitorTeamAbbr    136 non-null    object
#  7   homeFinalScore     136 non-null    int64
#  8   visitorFinalScore  136 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 9.7+ KB

# %%
max_home_score = nflgame['homeFinalScore'].max()
print(f"\nThe maximum value of the 'homeFinalScore' column is : {max_home_score}")

max_visitor_score = nflgame['visitorFinalScore'].max()
print(f"\nThe maximum value of the 'visitorFinalScore' column is : {max_visitor_score}")

min_home_score = nflgame['homeFinalScore'].min()
print(f"\nThe maximum value of the 'homeFinalScore' column is : {min_home_score}")

max_visitor_score = nflgame['visitorFinalScore'].min()
print(f"\nThe maximum value of the 'visitorFinalScore' column is : {max_visitor_score}")
# Out:
# The maximum value of the 'homeFinalScore' column is : 49
#
# The maximum value of the 'visitorFinalScore' column is : 48
#
# The maximum value of the 'homeFinalScore' column is : 3
#
# The maximum value of the 'visitorFinalScore' column is : 0

# %%
#Getting the result week and season data from the nfl dataset

week_number = 1

season_year = 2022

def nfl_week_season():
    try:
        
        if nflgame[(nflgame['week'] == week_number) & (nflgame['season'] == season_year)].empty:  #Check if the week and season is in the dataset
            
            print('No record data found')
        
        else:
            
            week_data = nflgame[(nflgame['week'] == week_number) & (nflgame['season'] == season_year)]  #Get the week and season data
            
            scores = week_data[['homeTeamAbbr', 'homeFinalScore', 'visitorTeamAbbr', 'visitorFinalScore']]
            
            print(scores)  #Print the final score data
    
    except Exception as e:  #If there is an error, print the error message
        
        print('No record data found')

nfl_week_season()
# Out:
#    homeTeamAbbr  homeFinalScore visitorTeamAbbr  visitorFinalScore
# 0            LA              10             BUF                 31
# 1           ATL              26              NO                 27
# 2           CAR              24             CLE                 26
# 3           CHI              19              SF                 10
# 4           CIN              20             PIT                 23
# 5           DET              35             PHI                 38
# 6           HOU              20             IND                 20
# 7           MIA              20              NE                  7
# 8           NYJ               9             BAL                 24
# 9           WAS              28             JAX                 22
# 10          ARI              21              KC                 44
# 11          LAC              24              LV                 19
# 12          MIN              23              GB                  7
# ...

# %%
nflgame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gameId             136 non-null    int64
#  1   season             136 non-null    int64
#  2   week               136 non-null    int64
#  3   gameDate           136 non-null    datetime64[ns]
#  4   gameTimeEastern    136 non-null    object
#  5   homeTeamAbbr       136 non-null    object
#  6   visitorTeamAbbr    136 non-null    object
#  7   homeFinalScore     136 non-null    int64
#  8   visitorFinalScore  136 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 9.7+ KB

# %%
sttsotog = nflgame.describe()

print("\nDescribe : \n", sttsotog)

print('\nShape :', nflgame.shape)
# Out:
# Describe :
#               gameId  season        week                       gameDate  \
# count  1.360000e+02   136.0  136.000000                            136
# mean   2.022099e+09  2022.0    4.845588  2022-10-07 19:03:31.764705792
# min    2.022091e+09  2022.0    1.000000            2022-09-08 00:00:00
# 25%    2.022093e+09  2022.0    3.000000            2022-09-25 00:00:00
# 50%    2.022101e+09  2022.0    5.000000            2022-10-09 00:00:00
# 75%    2.022102e+09  2022.0    7.000000            2022-10-23 00:00:00
# max    2.022111e+09  2022.0    9.000000            2022-11-07 00:00:00
# std    5.996614e+03     0.0    2.567254                            NaN
#
#        homeFinalScore  visitorFinalScore
# count      136.000000         136.000000
# mean        22.669118          20.948529
# min          3.000000           0.000000
# 25%         17.000000          14.750000
# 50%         22.500000          20.000000
# 75%         27.000000          27.000000
# ...

# %%
nflgame[['homeFinalScore', 'visitorFinalScore']].describe()
# Out:
#        homeFinalScore  visitorFinalScore
# count      136.000000         136.000000
# mean        22.669118          20.948529
# std          8.659874           9.731446
# min          3.000000           0.000000
# 25%         17.000000          14.750000
# 50%         22.500000          20.000000
# 75%         27.000000          27.000000
# max         49.000000          48.000000

# %%
nflgame.boxplot(column=['homeFinalScore', 'visitorFinalScore'])

plt.title('Boxplot of Home and Visitor Scores')

plt.xlabel('Team')

plt.ylabel('Final Score')

plt.show()

# %%
homeTeam_sum_score = nflgame.groupby('homeTeamAbbr')['homeFinalScore'].sum()

print('The total score of team on \033[1mHOME\033[0m ground is :',homeTeam_sum_score) 

visitorTeam_sum_score = nflgame.groupby('visitorTeamAbbr')['visitorFinalScore'].sum()

print('The total score of team on \033[1mVISITED\033[0m ground is :',visitorTeam_sum_score)

Score = [homeTeam_sum_score, visitorTeam_sum_score]
# Out:
# The total score of team on HOME ground is : homeTeamAbbr
# ARI    113
# ATL    131
# BAL    100
# BUF    106
# CAR     98
# CHI     81
# CIN    124
# CLE    134
# DAL    121
# DEN     45
# DET    158
# GB      86
# HOU     71
# IND     87
# JAX     91
# KC      97
# LA      89
# LAC     76
# LV      93
# MIA     73
# MIN    114
# NE      95
# NO     137
# NYG     79
# NYJ     98
# PHI    114
# PIT     54
# SEA     86
# SF      74
# TB     102
# TEN     63
# WAS     93
# Name: homeFinalScore, dtype: int64
# The total score of team on VISITED ground is : visitorTeamAbbr
# ARI     90
# ATL     86
# BAL    135
# BUF    114
# CAR     81
# CHI    106
# CIN    104
# CLE     66
# DAL     62
# DEN     76
# DET     30
# GB      68
# HOU     62
# IND     45
# JAX    108
# KC     146
# LA      42
# LAC    108
# LV      90
# MIA    140
# MIN     79
# NE     108
# NO      75
# NYG     84
# NYJ     98
# PHI    111
# PIT     66
# SEA    155
# SF     102
# TB      60
# TEN     86
# WAS     66
# ...

# %%
NFLDF = pd.DataFrame(Score)

print(NFLDF)

sttsotog = NFLDF.describe()

print(sttsotog)

print(NFLDF.shape)
# Out:
#                    ARI  ATL  BAL  BUF  CAR  CHI  CIN  CLE  DAL  DEN  ...   NO  \
# homeFinalScore     113  131  100  106   98   81  124  134  121   45  ...  137
# visitorFinalScore   90   86  135  114   81  106  104   66   62   76  ...   75
#
#                    NYG  NYJ  PHI  PIT  SEA   SF   TB  TEN  WAS
# homeFinalScore      79   98  114   54   86   74  102   63   93
# visitorFinalScore   84   98  111   66  155  102   60   86   66
#
# [2 rows x 32 columns]
#               ARI         ATL         BAL         BUF        CAR        CHI  \
# count    2.000000    2.000000    2.000000    2.000000   2.000000    2.00000
# mean   101.500000  108.500000  117.500000  110.000000  89.500000   93.50000
# std     16.263456   31.819805   24.748737    5.656854  12.020815   17.67767
# min     90.000000   86.000000  100.000000  106.000000  81.000000   81.00000
# 25%     95.750000   97.250000  108.750000  108.000000  85.250000   87.25000
# ...

# %%
teams = nflgame['homeTeamAbbr'].unique()

print(teams)

sotogDFT = NFLDF.T

print(sotogDFT)

collist = sotogDFT.columns.unique()

print(collist)

plt.figure(figsize=(18, 6))

plt.xlabel('Team Name (this is home team)')

plt.ylabel('Score')

plt.title('Scores for Each Team (HomeFinalScore and VisitorFinalScore)')

plt.xticks(rotation=30)  # Rotate the labels by 30 degrees

plt.grid(True)

for col in collist:

    plt.plot(teams,sotogDFT[col],label = col)

plt.legend()

plt.show()
# Out:
# ['LA' 'ATL' 'CAR' 'CHI' 'CIN' 'DET' 'HOU' 'MIA' 'NYJ' 'WAS' 'ARI' 'LAC'
#  'MIN' 'TEN' 'DAL' 'SEA' 'KC' 'BAL' 'CLE' 'JAX' 'NO' 'NYG' 'PIT' 'SF'
#  'DEN' 'LV' 'GB' 'BUF' 'PHI' 'IND' 'NE' 'TB']
#      homeFinalScore  visitorFinalScore
# ARI             113                 90
# ATL             131                 86
# BAL             100                135
# BUF             106                114
# CAR              98                 81
# CHI              81                106
# CIN             124                104
# CLE             134                 66
# DAL             121                 62
# DEN              45                 76
# DET             158                 30
# GB               86                 68
# HOU              71                 62
# IND              87                 45
# JAX              91                108
# KC               97                146
# LA               89                 42
# LAC              76                108
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

features = nflgame[['season', 'week']]  

target = nflgame['homeFinalScore']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)

print(f'homeFinalScore Mean Squared Error: {mse}')
# Out:
# homeFinalScore Mean Squared Error: 57.99277157535021

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

features = nflgame[['season', 'week']]  

target = nflgame['visitorFinalScore']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)

print(f'visitorFinalScore Mean Squared Error: {mse}')
# Out:
# visitorFinalScore Mean Squared Error: 119.41157532241816

# %% [markdown]
# # **Thank You !**
